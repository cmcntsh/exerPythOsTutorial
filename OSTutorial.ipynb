# %%
import os

# %%
print(dir(os))
# Out:
# ['CLD_CONTINUED', 'CLD_DUMPED', 'CLD_EXITED', 'CLD_TRAPPED', 'DirEntry', 'EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_LOCK', 'F_OK', 'F_TEST', 'F_TLOCK', 'F_ULOCK', 'MutableMapping', 'NGROUPS_MAX', 'O_ACCMODE', 'O_APPEND', 'O_ASYNC', 'O_CLOEXEC', 'O_CREAT', 'O_DIRECTORY', 'O_DSYNC', 'O_EXCL', 'O_EXLOCK', 'O_NDELAY', 'O_NOCTTY', 'O_NOFOLLOW', 'O_NONBLOCK', 'O_RDONLY', 'O_RDWR', 'O_SHLOCK', 'O_SYNC', 'O_TRUNC', 'O_WRONLY', 'POSIX_SPAWN_CLOSE', 'POSIX_SPAWN_DUP2', 'POSIX_SPAWN_OPEN', 'PRIO_PGRP', 'PRIO_PROCESS', 'PRIO_USER', 'P_ALL', 'P_NOWAIT', 'P_NOWAITO', 'P_PGID', 'P_PID', 'P_WAIT', 'PathLike', 'RTLD_GLOBAL', 'RTLD_LAZY', 'RTLD_LOCAL', 'RTLD_NODELETE', 'RTLD_NOLOAD', 'RTLD_NOW', 'R_OK', 'SCHED_FIFO', 'SCHED_OTHER', 'SCHED_RR', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'ST_NOSUID', 'ST_RDONLY', 'TMP_MAX', 'WCONTINUED'
# ...

# %%
print(os.getcwd())
# Out:
# /Users/reinhardts/Documents/myProject/NURS 6806/exerPythOsTutorial

# %%
os.chdir("/Users/reinhardts/Documents/")

# %%
"OS-Demo-2"
# Out:
# 'OS-Demo-2'

# %%
os.listdir()
# Out:
# ['README.md', '.ipynb_checkpoints', '.git', 'OSTutorial.ipynb']

# %%
os.mkdir("OS-Demo-2.txt")

# %%
os.makedirs("OS-Demo-2/Sub-Dir-1.txt")

# %%
os.rmdir("OS-Demo-2.txt")

# %%
os.removedirs("OS-Demo-2/Sub-Dir-1.txt")

# %%
os.chdir("/Users/reinhardts/Documents/myProject/NURS 6806/exerPythOsTutorial")

# %%
print(os.listdir())
# Out:
# ['README.md', '.ipynb_checkpoints', 'Test.rtf', '.git', 'OSTutorial.ipynb']

# %%
os.rename("Test.rtf", "demo.rtf")

# %%
print(os.listdir())
# Out:
# ['demo.rtf', 'README.md', '.ipynb_checkpoints', '.git', 'OSTutorial.ipynb']

# %%
print(os.stat("demo.rtf"))
# Out:
# os.stat_result(st_mode=33188, st_ino=17109594, st_dev=16777224, st_nlink=1, st_uid=501, st_gid=20, st_size=365, st_atime=1631667175, st_mtime=1631667173, st_ctime=1631667561)

# %%
from datetime import datetime

# %%
mod_time = os.stat("demo.rtf").st_mtime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# 2021-09-14 18:52:53.779065

# %%
for dirpath, dirnames, filenames in os.walk("/Users/reinhardts/Documents/"):
    print('Current Path:', dirpath)
    print("Directories:", dirnames)
    print("Files:", filenames)
# Out:
# Current Path: /Users/reinhardts/Documents/
# Directories: ['Kira Lee Professional Documents', 'myProject', 'Kiralee Fambam', 'Zoom', 'iCloud Photos_files', 'Family Pictures', 'exerGitPractice']
# ...

# %%
print (os.environ.get('HOME'))
# Out:
# /Users/reinhardts

# %%
file_path = os.environ.get("HOME") + "test.rtf"
print(file_path)
# Out:
# /Users/reinhardtstest.rtf

# %%
file_path = os.path.join(os.environ.get("HOME"),"test.rtf")
print(file_path)
# Out:
# /Users/reinhardts/test.rtf

# %%
print(os.path.basename("/tmp/test.rtf"))
# Out:
# test.rtf

# %%
print(os.path.dirname("/tmp/test.rtf"))
# Out:
# /tmp

# %%
print(os.path.split("/tmp/test.rtf"))
# Out:
# ('/tmp', 'test.rtf')

# %%
print(os.path.exist("/tmp/test.rtf"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-00bfd40b3b73> in <module>
# ----> 1 print(os.path.exist("/tmp/test.rtf"))
#
# AttributeError: module 'posixpath' has no attribute 'exist'

# %%
print(os.path.isdir("/tmp/test.rtf"))
# Out:
# False

# %%
print(os.path.isfile("/tmp/test.rtf"))
# Out:
# False

# %%
print(os.path.splittext("/tmp/test.rtf"))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-80-c443e8a1cd95> in <module>
# ----> 1 print(os.path.splittext("/tmp/test.rtf"))
#
# AttributeError: module 'posixpath' has no attribute 'splittext'

# %%
import os
BASE_URL = os.environ.get(BASE_URL,"http://localhost:8891/notebooks/Documents/myProject/NURS%206806/exerPythOsTutorial/OSTutorial.ipynb"). rstrip("")
def build_api_url(book_id, format, token):
    return f"{BASE_URL}/api/v1/book/{book_id}?format={format}&token={token}"
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-86-b16f1bcceb04> in <module>
#       1 import os
# ----> 2 BASE_URL = os.environ.get(BASE_URL,"http://localhost:8891/notebooks/Documents/myProject/NURS%206806/exerPythOsTutorial/OSTutorial.ipynb"). rstrip("")
#       3 def build_api_url(book_id, format, token):
#       4     return f"{BASE_URL}/api/v1/book/{book_id}?format={format}&token={token}"
#
# NameError: name 'BASE_URL' is not defined

# %%
I tried to create a URL but kept running into this issue

# %%
In the last question, do you mean the documentation in the transcript? I cannot find it
